# %% [markdown]
# # FORESEE - AM

# %% [markdown]
# ### Load Libraries

# %%
import numpy as np
from src.foresee import Foresee, Utility, Model

# %% [markdown]
# ## 1. Initialization

# %% [markdown]
# All function that we will need are included in the FORESEE package. We start by simply initializing it:

# %%
foresee = Foresee()

# %% [markdown]
# If MCPs are sufficiently light, they are mainly produced via pion decay. To start, let us have a look at the pion spectrum in terms of the angle with respect to the beam axis $\theta$ and the momentum $p$. This can be done using the function `get_spectrumplot` which requires the MC particle ID (or simply pid), the MC generator and the energy. The units on the coloraxis are pb/bin.
#
# FORESEE provides the 2D spectrum as tables for a variety of particles ($\pi^0$, $\eta$, ...), generators (SIBYLL, EPOSLHC, QGSJET, PYTHIA). The datafiles are stored in the directory `files/hadrons`.

# %%
plot=foresee.get_spectrumplot(pid="111", generator="EPOSLHC", energy="14")
plot.show()

# %% [markdown]
# ## 2. Specifying the Model: AM

# %% [markdown]
# The phenomenology of the dark states with AM can be described by the following Lagrangian
#
# \begin{equation}
#  \mathcal{L} = - m_\chi \bar \chi \chi -  a_\chi \bar{\chi} \gamma^\mu \gamma^5 \chi \partial^\nu F_{\mu \nu}
# \end{equation}
#
# with the dark state mass $m_\chi$ and the AM $a_\chi$ as free parameters. For the search for dark states with AM at forward experiments we need to know i) the *production rate*, and ii) the *interaction rate*. All these properties are specified in the `Model` class. We initialize it with the name of the model as argument.

# %%
energy = "14" # CM energy of LHC in unit of TeV
modelname="AM"
model = Model(modelname)

# %% [markdown]
# **Production** Most light dark sector particles are produced in the decay of primary particles. Here we need to specify the total branching fraction into the dark sector as function of the `coupling` and the `mass`. We additionally specify the variable `nsample` which specifies how often each parent particle is decayed.
#
# In the simplest case, the dark state with AM is produced via two body decays of vector mesons $M \to \bar \chi \chi$ with $M = \rho, \omega, \phi, J/\psi, \psi(2S)$ and $\Upsilon(nS)$. The corresponding branching fractions are given by
#
# \begin{equation}
# \frac{\text{BR}(M \!\to\! \chi\bar\chi)}{\text{BR}(M \!\to\! ee) }
# = \dfrac{a_\chi^2 m_M^4}{4\pi\alpha}
# \frac{(m_M^2 \!-\!4m_\chi^2)(m_M^2 \!-\! 4m_\chi^2)^{1/2}} {(m_M^2 \!+\! 2m_e^2)(m_M^2 \!-\! 4m_e^2)^{1/2}} \ .
# \end{equation}
#
# The benchmark value of $a_\chi$ is taken to be $1\,{\rm GeV}^{-2}$.

# %%
nsample = 50

# rho decay 
model.add_production_2bodydecay(
    pid0 = "113",
    pid1 = "0",
    br = "2 * 4.72e-5 * coupling**2 *(0.77545**4.)/(4.*np.pi/137.) * ((1-4*(mass/0.77545)**2)*np.sqrt(1-4*(mass/0.77545)**2) )/( (1+2*(0.000511/0.77545)**2)*np.sqrt(1-4*(0.000511/0.77545)**2) )",
    generator = "EPOSLHC",
    energy = energy,
    nsample = nsample,
)

# omega decay
model.add_production_2bodydecay(
    pid0 = "223",
    pid1 = "0",
    br = "2 * 7.36e-5 * coupling**2 *(0.78266**4.)/(4.*np.pi/137.) * ((1-4*(mass/0.78266)**2)*np.sqrt(1-4*(mass/0.78266)**2) )/( (1+2*(0.000511/0.78266)**2)*np.sqrt(1-4*(0.000511/0.78266)**2) )",
    generator = "EPOSLHC",
    energy = energy,
    nsample = nsample,
)

# phi decay
model.add_production_2bodydecay(
    pid0 = "333",
    pid1 = "0",
    br = "2 * 2.97e-4 * coupling**2 *(1.019461**4.)/(4.*np.pi/137.) * ((1-4*(mass/1.019461)**2)*np.sqrt(1-4*(mass/1.019461)**2) )/( (1+2*(0.000511/1.019461)**2)*np.sqrt(1-4*(0.000511/1.019461)**2) )",
    generator = "EPOSLHC",
    energy = energy,
    nsample = nsample,
)

# J/psi decay
model.add_production_2bodydecay(
    pid0 = "443",
    pid1 = "0",
    br = "2 * 0.0597 * coupling**2  *(3.096**4.)/(4.*np.pi/137.) * ((1-4*(mass/3.096)**2)*np.sqrt(1-4*(mass/3.096)**2) )/( (1+2*(0.000511/3.096)**2)*np.sqrt(1-4*(0.000511/3.096)**2) )",
    generator = "Pythia8",
    energy = energy,
    nsample = nsample,
)

# psi (2S) decay
model.add_production_2bodydecay(
    pid0 = "100443",
    pid1 = "0",
    br = "2 * 0.00993 * coupling**2  *(3.686**4.)/(4.*np.pi/137.) * ((1-4*(mass/3.686)**2)*np.sqrt(1-4*(mass/3.686)**2) )/( (1+2*(0.000511/3.686)**2)*np.sqrt(1-4*(0.000511/3.686)**2) )",
    generator = "Pythia8",
    energy = energy,
    nsample = nsample,
)
 
# Upsilon decay        
model.add_production_2bodydecay(
    pid0 = "553",
    pid1 = "0",
    br = "2 * 0.0238 * coupling**2 *(9.460**4.)/(4.*np.pi/137.) * ((1-4*(mass/9.460)**2)*np.sqrt(1-4*(mass/9.460)**2) )/( (1+2*(0.000511/9.460)**2)*np.sqrt(1-4*(0.000511/9.460)**2) )",
    generator = "Pythia8",
    energy = energy,
    nsample = nsample,
)

# Upsilon (2S) decay        
model.add_production_2bodydecay(
    pid0 = "100553",
    pid1 = "0",
    br = "2 * 0.0191 * coupling**2  *(10.023**4.)/(4.*np.pi/137.) * ((1-4*(mass/10.023)**2)*np.sqrt(1-4*(mass/10.023)**2) )/( (1+2*(0.000511/10.023)**2)*np.sqrt(1-4*(0.000511/10.023)**2) )",
    generator = "Pythia8",
    energy = energy,
    nsample = nsample,
)

# Upsilon (3S) decay  
model.add_production_2bodydecay(
    pid0 = "200553",
    pid1 = "0",
    br = "2 * 0.0218 * coupling**2  *(10.355**4.)/(4.*np.pi/137.) * ((1-4*(mass/10.355)**2)*np.sqrt(1-4*(mass/10.355)**2) )/( (1+2*(0.000511/10.355)**2)*np.sqrt(1-4*(0.000511/10.355)**2) )",
    generator = "Pythia8",
    energy = energy,
    nsample = nsample,
)

# %% [markdown]
# The dark state with AM can also be produced in 3-body decays of pseudoscalar mesons $M \to \gamma \bar\chi \chi$ via an offshell photon. This can be added using the function `add_production_3bodydecay()`. It requires to provide `br` which is the differential branching fraction $d\text{BR}/(dq^2 \ d\cos\theta)$ where $q^2=(p_{\chi_1}+p_{\chi_2})^2$ and $\theta$ is the angle between $p_{\chi_1}$ in the restframe of $p_{\chi_1}+p_{\chi_2}$ and the direction of $p_{\chi_1}+p_{\chi_2}$ in the restframe of $M$. The reason for this choice of coordinates it simplified the integration boundaries. The differential branching fraction for this process is given by
#
# \begin{equation}
# \frac{d\text{BR}(M \!\to\! \gamma\chi\chi)}{dq^2 \, d\!\cos\theta}
#  = \frac{a_\chi^2 q^2}{16 \pi^2} \Big[1\!-\!\frac{q^2}{m_M^2}\Big]^3 \Big[1-\frac{4m_\chi^2}{q^2}\Big]^{\frac12}
#   \times  \Big(1-\frac{4m_\chi^2}{q^2} \Big) \times (2- \sin^2 \theta )   \times \text{BR}(M \!\to \!\gamma\gamma)
# \end{equation}
#
# Since we have two $\chi$'s in the final state, we multiply by an additional factor 2. In the formulas below $q$ and $\theta$ are expressed as `q` and `th`.

# %%
nsample = 20

# pion decay
model.add_production_3bodydecay(
    pid0 = "111",
    pid1 = "22",
    pid2 = "0",
    br = "2.*0.99 * coupling**2 * (q**2.)/16./(np.pi**2.) * (1-q**2/0.135**2)**3 * (1-4*mass**2/q**2)**0.5 * (1-4*mass**2/q**2)*(2.- np.sin(th)**2)",
    generator = "EPOSLHC",
    energy = energy,
    nsample = nsample,
)

# eta decay
model.add_production_3bodydecay(
    pid0 = "221",
    pid1 = "22",
    pid2 = "0",
    br = "2.*0.39 * coupling**2 * (q**2.)/16./(np.pi**2.) * (1-q**2/0.547**2)**3 * (1-4*mass**2/q**2)**0.5 * (1-4*mass**2/q**2)*(2. - np.sin(th)**2)",
    generator = "EPOSLHC",
    energy = energy,
    nsample = nsample,
)

# eta' decay
model.add_production_3bodydecay(
    pid0 = "331",
    pid1 = "22",
    pid2 = "0",
    br = "2.*0.023 * coupling**2 *(q**2.)/16./(np.pi**2.) * (1-q**2/0.957**2)**3 * (1-4*mass**2/q**2)**0.5 * (1-4*mass**2/q**2)*(2. - np.sin(th)**2)",
    generator = "EPOSLHC",
    energy = energy,
    nsample = nsample,
)

# %% [markdown]
# Particles can also be produced directly in collisions. In the case of dark states with AM, this proceeds through Drell-Yan production, which is relevant at higher masses. The spectra for LLPs at some reference coupling need to be provided in the `files/direct` directory. (not done yet)

# %%
model.add_production_direct(
    label = "DY",
    energy = energy,
    coupling_ref=1,
    masses = [
        1.001, 1.122, 1.258, 1.412, 1.501, 1.541, 1.549, 1.584, 1.778, 1.801, 
        1.821, 1.841, 1.844, 1.995, 2.238, 2.511, 2.818, 3.162, 3.548, 3.981, 
        4.466, 4.601, 4.666, 4.701, 4.731, 4.901, 5.011, 5.012, 5.101, 5.171, 
        5.178, 5.623, 6.309, 7.079, 7.943, 8.912, 10.01, 11.22, 12.58, 14.12, 
        15.84, 17.78, 19.95, 22.38, 25.11, 28.18, 31.62, 35.48, 39.81, 44.66, 
        50.11, 56.23, 63.09, 70.79, 79.43, 89.12, 100.01
    ]
)

# %% [markdown]
# **Interaction Rate:** To estimate the number of scattering events, we need to know the differential scattering rate with respect to the recoil energy $d\sigma/dE_r$ which in general depends is a function of the coupling $g$ (or `coupling`), the particle mass $m$ (or `mass`), the particles incoming energy $E$ (or `energy`) and the recoil energy $E_R$ (or `recoil`).  In most models can be written as $\ d\sigma/dE_r(m,g,E,E_R)\  =\  d\sigma/dE_r (m,g_*, E,E_R) \ \cdot\  g_*^2 \ / \ g^{2}$ where $g_*$ is some reference coupling. In this case, we can provide  $d\sigma/dE_r (m,g_*, E,E_R)$ at a reference coupling $g_*$ using `model.set_dsigma_drecoil_1d()`. Alternatively, one can also provide $d\sigma/dE_r(m,g,E,E_R)$ via `model.model.set_dsigma_drecoil_2d()`, which is probably a bit slower.
#
# For DM with AM, we can follow Eq. (6) of [1902.03246](https://arxiv.org/pdf/1902.03246.pdf) and write
# \begin{equation}
# \frac{d\sigma}{dE_R} =  \frac{\alpha b_\chi^2 }{E_{\chi }^2 } \times \left(
#                           2 m_e  E_{\chi }^2 + E_R  m_{\chi }^2  \right)
# \end{equation}

# %%
model.set_dsigma_drecoil_1d(
    dsigma_der="1./137 * (2*0.000511 + recoil*mass**2/energy**2)", 
    recoil_max = "2 * 0.000511 * (energy**2-mass**2) / (0.000511*(2*energy+mass) + mass**2)",
    coupling_ref=1
)

# %% [markdown]
# ## 3. Generate LLP Spectra

# %% [markdown]
# After we have specified the model, let us generate the LLP spectra. We first set the model we just created.

# %%
foresee.set_model(model=model)

# %% [markdown]
# Let's first look at one benchmark scenario with $m_{\chi}=1$ GeV and $g=1$ using the function `foresee.get_llp_spectrum()`.

# %%
plt = foresee.get_llp_spectrum(1, coupling=1, do_plot=True)
plt.show()
# Out:
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.npy')

# %% [markdown]
# We can now produce a set of LLP spectra for various masses (chosen to be equally spaced in log(mass)) and unit coupling and save them.

# %%
# full mass set
masses_all = [
    # equally spaced in log-space
    0.01001, 0.01122, 0.01258, 0.01412, 0.01584, 0.01778, 0.01995, 0.02238, 0.02511, 0.02818, 
    0.03162, 0.03548, 0.03981, 0.04466, 0.05011, 0.05623, 0.06309, 0.07079, 0.07943, 0.08912,
    0.1001, 0.1122, 0.1258, 0.1412, 0.1584, 0.1778, 0.1995, 0.2238, 0.2511, 0.2818, 
    0.3162, 0.3548, 0.3981, 0.4466, 0.5011, 0.5623, 0.6309, 0.7079, 0.7943, 0.8912,
    1.001, 1.122, 1.258, 1.412, 1.584, 1.778, 1.995, 2.238, 2.511, 2.818, 
    3.162, 3.548, 3.981, 4.466, 5.011, 5.623, 6.309, 7.079, 7.943, 8.912,
    10.01, 11.22, 12.58, 14.12, 15.84, 17.78, 19.95, 22.38, 25.11, 28.18, 
    31.62, 35.48, 39.81, 44.66, 50.11, 56.23, 63.09, 70.79, 79.43, 89.12, 100.01, 
    # extra points near thresholds
    0.333, 0.365, 0.386, 0.392, 0.475, 0.51, 1.501, 1.541, 1.549, 1.801, 1.821, 
    1.841, 1.844, 4.601, 4.666, 4.701, 4.731, 4.901, 5.012, 5.101, 5.171, 5.178 
]

#reduced set (is quicker)
masses_reduced = [
    0.01001, 0.01258, 0.01584, 0.01995, 0.02511, 0.03162, 0.03981, 0.05011, 0.06309, 0.07943, 
    0.1001, 0.1258, 0.1584, 0.1995, 0.2511, 0.3162, 0.3981, 0.5011, 0.6309, 0.7943, 
    1.001, 1.258, 1.584, 1.995, 2.511, 3.162, 3.981, 5.011, 6.309, 7.943, 
    10.01, 12.58, 15.84, 19.95, 25.11, 31.62, 39.81, 50.11, 63.09, 79.43, 100.01, 
    0.365, 0.392, 0.475, 1.501, 1.549, 1.801, 1.844, 4.601, 4.731, 4.901, 5.012,5.178 
]

masses = sorted(masses_all)
for mass in masses:
    foresee.get_llp_spectrum(mass=mass,coupling=1)
# Out:
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.01995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.02238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.02511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.02818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.03162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.03548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.03981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.04466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.05011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.05623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_111_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.06309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.07079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.07943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.08912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.1995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.2238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_221_m_0.2511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.2818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.3162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.333.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.3548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.365.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_113_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_223_m_0.386.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.392.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.3981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.4466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_331_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.475.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.5011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.5011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.5011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_333_m_0.5011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.5011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.5011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.51.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.51.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.51.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.51.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.51.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.5623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.5623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.5623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.5623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.5623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.6309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.6309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.6309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.6309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.6309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.7079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.7079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.7079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.7079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.7079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.7943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.7943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.7943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.7943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.7943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_0.8912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_0.8912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_0.8912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_0.8912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_0.8912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.001.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.122.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.258.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.412.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.501.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.501.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.501.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.501.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.501.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.501.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_443_m_1.541.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.541.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.541.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.541.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.541.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.541.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.549.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.549.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.549.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.549.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.549.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.584.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.778.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.801.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.801.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.801.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.801.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.801.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.821.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.821.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.821.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.821.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.821.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.841.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100443_m_1.841.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.841.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.841.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.841.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.844.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.844.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.844.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.844.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_1.995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_1.995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_1.995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_1.995.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_2.238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_2.238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_2.238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_2.238.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_2.511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_2.511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_2.511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_2.511.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_2.818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_2.818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_2.818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_2.818.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_3.162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_3.162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_3.162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_3.162.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_3.548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_3.548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_3.548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_3.548.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_3.981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_3.981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_3.981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_3.981.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_4.466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_4.466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_4.466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_4.466.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_4.601.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_4.601.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_4.601.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_4.601.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_4.666.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_4.666.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_4.666.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_4.666.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_4.701.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_4.701.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_553_m_4.701.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_4.701.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_4.731.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_4.731.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_4.731.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_4.901.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_4.901.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_4.901.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_5.011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_5.011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_100553_m_5.011.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_5.012.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_5.012.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_5.101.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_5.101.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_5.171.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_200553_m_5.171.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_5.178.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_5.623.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_6.309.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_7.079.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_7.943.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_8.912.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_10.01.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_11.22.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_12.58.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_14.12.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_15.84.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_17.78.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_19.95.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_22.38.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_25.11.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_28.18.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_31.62.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_35.48.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_39.81.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_44.66.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_50.11.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_56.23.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_63.09.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_70.79.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_79.43.npy')
# ('save data to file:', 'files/models/AM/LLP_spectra/14TeV_DY_m_89.12.npy')
# ('did not find file:', 'files/direct/14TeV/AM/DY_14TeV_100.01.txt', 'or', 'files/direct/14TeV/AM/DY_14TeV_10000000000.0.txt')

# %% [markdown]
# ## 4. Count Eventrate in Detector

# %% [markdown]
# Before counting the number of decays within the detector volume, let us specify the detector geometry. For this we need
#
# - the `distance` of the detectot from the IP in meter (default: 480)
# - the `length` of the detector in meter (default: 5)
# - the `luminosity` in units of fb^-1 (default: 3000)
# - the `selection` depending in `x.x` and `x.y` (default: `np.sqrt(x.x**2 + x.y**2)< 1`)
# - the `numberdensity` of target particles in the detector in $1/m^3$ (default: 3.754e+29 for LAr)
# - the `ermin` and `ermax` as minimum and maximum recoil energy of the analysis (default: 0.03 and 1 GeV)
#
# The default correspond to the FASER2 detector (for LLP seraches). For FLArE10 we need to modify things a bit.

# %%
distance, selection, length, luminosity = 620, "abs(x.x)<0.5 and abs(x.y)<0.5", 7, 3000
numberdensity , ermin, ermax = 3.754e+29, 0.03, 1.
foresee.set_detector(
    distance=distance, selection=selection, length=length, luminosity=luminosity, 
    numberdensity=numberdensity, ermin=ermin, ermax=ermax)

# %% [markdown]
# Let us look for one specific dark photon mass $m_{\chi}=1$ GeV at how many particle decay inside the decay volume. This can be done using `get_events_interaction()` for which we need to specify again the mass and filename. Additionally, we can specify
#
# - the `couplings` for which we evaluate the event rate as numpy array (default `np.logspace(-8,-3,51)`)
# - the `preselectioncuts` when reading the LLP spectra in terms of momentum `p` and angle `th` (default: `th<0.01 and p>100`)
# - the number `nsample` describing how many randomly choosen values of $\phi_{LLP}$ should sampled (default 1). This is only relevant for detectors that are not cylyndrical or not centered around the beam axis.
# - the production `modes` which should be considered
# - the `energy` of the experiments

# %%
mass = 1.001
output = foresee.get_events_interaction(mass=mass, energy=energy, couplings=np.logspace(-5,0,6), nsample=1)
coups, nsigs, energies, weights, _ = output
for coup,nsig in zip(coups, nsigs):
    print ("g =", '{:5.3e}'.format(coup), ": nsig =", '{:5.3e}'.format(nsig))
# Out:
# ('g =', '1.000e-05', ': nsig =', '1.947e-12')
# ('g =', '1.000e-04', ': nsig =', '1.947e-08')
# ('g =', '1.000e-03', ': nsig =', '1.947e-04')
# ('g =', '1.000e-02', ': nsig =', '1.947e+00')
# ('g =', '1.000e-01', ': nsig =', '1.947e+04')
# ('g =', '1.000e+00', ': nsig =', '1.947e+08')

# %% [markdown]
# The previous function also outputs the energy distribution of the dark photons which decay inside the detector. Let's have a look at them.

# %%
fig = plt.figure(figsize=(7,5))
ax = plt.subplot(1,1,1)
for coup,en,weight in zip(coups,energies,weights):
    if sum(weight)<10**-5 : continue
    ax.hist(en, weights=weight, bins=np.logspace(2,4, 20), histtype='step', label=r"$\epsilon=$"+str(coup)) 
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_ylim(10**-7,10**5) 
    ax.set_xlabel("E(a) [GeV]") 
    ax.set_ylabel("Number of Events per bin") 
    ax.legend(frameon=False, labelspacing=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Parameter Scan

# %% [markdown]
# In the following, we will get the LLP sensitivity reach for different detector configuraions. As an example, we show the FASER2 reach for dark photons for 3 scenarios. We just need to loop over different masses and use the previously introduced funtion `get_events`. The results will be written into a `.npy` file that we can store and plot later.

# %% [markdown]
# - the nominal/default setup

# %%
#specify setup
luminosity, distance, length = 3000, 620, 7
setup, selection, channels = "default", "abs(x.x)<0.5 and abs(x.y)<0.5", None
numberdensity, ermin, ermax = 3.754e+29, 0.03, 1
foresee.set_detector(distance=distance, selection=selection, length=length, luminosity=luminosity, 
    numberdensity=numberdensity, ermin=ermin, ermax=ermax, )

#get reach 
list_nevents = []    
for mass in masses:
    print "Do", mass
    outout=foresee.get_events_interaction(mass=mass, energy=energy, couplings = np.logspace(-5,0,51), nsample=5)
    couplings, nevents, _, _ , _ = outout
    list_nevents.append(nevents)  
    
#save results
np.save("files/models/"+modelname+"/results/"+energy+"TeV_"+setup+".npy",[masses,couplings,list_nevents])
# Out:
# Do 0.01001
# Do 0.01122
# Do 0.01258
# Do 0.01412
# Do 0.01584
# Do 0.01778
# Do 0.01995
# Do 0.02238
# Do 0.02511
# Do 0.02818
# Do 0.03162
# Do 0.03548
# Do 0.03981
# Do 0.04466
# Do 0.05011
# Do 0.05623
# Do 0.06309
# Do 0.07079
# Do 0.07943
# Do 0.08912
# Do 0.1001
# Do 0.1122
# Do 0.1258
# Do 0.1412
# Do 0.1584
# Do 0.1778
# Do 0.1995
# Do 0.2238
# Do 0.2511
# Do 0.2818
# Do 0.3162
# Do 0.333
# Do 0.3548
# Do 0.365
# Do 0.386
# Do 0.392
# Do 0.3981
# Do 0.4466
# Do 0.475
# Do 0.5011
# Do 0.51
# Do 0.5623
# Do 0.6309
# Do 0.7079
# Do 0.7943
# Do 0.8912
# Do 1.001
# Do 1.122
# Do 1.258
# Do 1.412
# Do 1.501
# Do 1.541
# Do 1.549
# Do 1.584
# Do 1.778
# Do 1.801
# Do 1.821
# Do 1.841
# Do 1.844
# Do 1.995
# Do 2.238
# Do 2.511
# Do 2.818
# Do 3.162
# Do 3.548
# Do 3.981
# Do 4.466
# Do 4.601
# Do 4.666
# Do 4.701
# Do 4.731
# Do 4.901
# Do 5.011
# Do 5.012
# Do 5.101
# Do 5.171
# Do 5.178
# Do 5.623
# Do 6.309
# Do 7.079
# Do 7.943
# Do 8.912
# Do 10.01
# Do 11.22
# Do 12.58
# Do 14.12
# Do 15.84
# Do 17.78
# Do 19.95
# Do 22.38
# Do 25.11
# Do 28.18
# Do 31.62
# Do 35.48
# Do 39.81
# Do 44.66
# Do 50.11
# Do 56.23
# Do 63.09
# Do 70.79
# Do 79.43
# Do 89.12
# Do 100.01

# %% [markdown]
# ## 6. Plot the Results - Configurations

# %% [markdown]
# Now let's plot the results. We first specify all detector setups for which we want to show result (filename in model/results directory, label, color, linestyle, opacity alpha for filled contours, required number of events).

# %%
setups = [
    ["14TeV_default.npy",    "default"  , "red",     "solid", 0., 3],
]

# %% [markdown]
# Then we specify all the existing bounds (filename in model/bounds directory, label, label position x, label position y, label rotation)

# %%
bounds = [   
    ["bounds_all.txt",         "",  0.100, 1.9*10**-7, 25  ],
]

# %% [markdown]
# We then specify other projected sensitivitities (filename in model/bounds directory, color, label, label position x, label position y, label rotation)

# %%
projections = [
#    ["limits_Belle2-3gamma.txt",   "royalblue",   r"Belle2 $3\gamma$"  , 1.400, 1.7*10**-4, 0  ],
]

# %% [markdown]
# Finally, we can plot everything using `foresee.plot_reach()`. It returns a matplotlib instance, to which we can add further lines and which we can show or save. Below, we add the dark matter relict target line for a specific benchmark.

# %%
plot = foresee.plot_reach(
    setups=setups,
    bounds=bounds,
    projections=[],
    title="AM", 
    xlims = [0.01,100], 
    ylims = [10**-7,1],
    xlabel=r"DM Mass $m_{\chi}$ [GeV]", 
    ylabel=r"anapol moment $a_\chi$ [GeV$^{-2}$]",
    legendloc=(1,0.28),
    figsize=(8,6),
)

#plot.subplots_adjust(left=0.12, right=0.97, bottom=0.10, top=0.95)
plot.savefig("/Users/felixkling/Downloads/Figure_AM_Reach.pdf")
plot.show()

# %% [markdown]
# ## 7. Plot Production Cross Section
#
# We can also plot the production cross section as a function of the particle mass via `foresee.plot_production`. We do this below to show the production rate associated with different channels:

# %%
productions = [
    ["111"    , None      , "firebrick"   , r"$\pi$"         ],   
    ["221"    , None      , "red"         , r"$\eta$"        ],   
    ["331"    , [0.03,10] , "salmon"      , r"$\eta'$"       ],  
    ["113"    , [0.03,10] , "dodgerblue"  , r"$\rho$"        ],   
    ["223"    , [0.03,10] , "blue"        , r"$\omega$"      ],   
    ["333"    , [0.03,10] , "deepskyblue" , r"$\phi$"        ],  
    ["443"    , [0.3,10]  , "gold"        , r"$J/\psi$"      ],   
    ["100443" , [0.3,10]  , "orange"      , r"$\psi(2S)$"    ],  
    ["553"    , [0.8,10]  , "green"       , r"$\Upsilon(1S)$"],   
    ["100553" , [0.8,10]  , "limegreen"   , r"$\Upsilon(2S)$"],  
    ["200553" , [0.8,10]  , "lime"        , r"$\Upsilon(3S)$"],  
    ["DY"     , [0.3,102] , "gray"        , "DY"             ],   
]

foresee.plot_production(
    masses = sorted(masses_all), 
    productions = productions,
    condition="True", 
    xlims=[0.01,100],ylims=[10**5,10**12], 
    xlabel=r"DM Mass [GeV]", 
    ylabel=r"Production Rate $\sigma/\epsilon^2$ [pb]",
    legendloc=(1.02,1.02),
    fs_label=12,
    title="All DM with AM",
)

#plot.subplots_adjust(left=0.12, right=0.97, bottom=0.10, top=0.95)
plot.savefig("/Users/felixkling/Downloads/Figure_AM_Prod_All.pdf")
plot.show()

# %% [markdown]
# We can also also do this after applying additional conditions. Below we do this by requireing the particle to be within 1 mrad within the beam axis using the `condition` option.

# %%
foresee.plot_production(
    masses = sorted(masses_all), 
    productions = productions,
    condition="logth<-3", 
    xlims=[0.01,100],ylims=[10**2,10**9], 
    xlabel=r"DM Mass [GeV]", 
    ylabel=r"Production Rate $\sigma/\epsilon^2$ [pb]",
    legendloc=(1.02,1.02),
    fs_label=12,
    title="DM with AM within 1mrad of LoS"
)

#plot.subplots_adjust(left=0.12, right=0.97, bottom=0.10, top=0.95)
plot.savefig("/Users/felixkling/Downloads/Figure_AM_Prod_1mrad.pdf")
plot.show()
